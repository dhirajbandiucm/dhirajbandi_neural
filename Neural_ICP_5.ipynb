# %%
#Dhiraj Bandi #700760856
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras.optimizers import Adadelta
from keras.callbacks import EarlyStopping
from keras.datasets import fashion_mnist
import numpy as np
import matplotlib.pyplot as plt

# Define the encoding dimension
encoding_dim = 48  # Increased encoding dimension for more representation capacity

# Define the input placeholder
input_img = Input(shape=(784,))

# Add layers to the autoencoder
encoded = Dense(128, activation='relu')(input_img)  # New hidden layer with 128 units
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Original encoding layer

decoded = Dense(128, activation='relu')(encoded)  # New hidden layer with 128 units for decoding
decoded = Dense(784, activation='sigmoid')(decoded)  # Output layer

# Define the autoencoder model
autoencoder = Model(input_img, decoded)

# Compile the autoencoder model with the original optimizer
autoencoder.compile(optimizer=Adadelta(), loss='binary_crossentropy')

# Load the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5)  # Added early stopping to prevent overfitting

# Train the autoencoder model
history = autoencoder.fit(x_train, x_train,
                epochs=50,  # Increased number of epochs for potentially better training
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[early_stopping])  # Added early stopping callback

# Predict the reconstructed test set
reconstructed_imgs = autoencoder.predict(x_test)

# Compute the Mean Squared Error (MSE) for each sample
mse = np.mean(np.power(x_test - reconstructed_imgs, 2), axis=1)

# Calculate the mean reconstruction error
mean_mse = np.mean(mse)

print(f'Mean Reconstruction Error (MSE) on test set: {mean_mse}')
# Out:
# Epoch 1/50
# 235/235 [==============================] - 5s 17ms/step - loss: 0.6932 - val_loss: 0.6932
# Epoch 2/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.6931 - val_loss: 0.6931
# Epoch 3/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 4/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6929 - val_loss: 0.6929
# Epoch 5/50
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6928 - val_loss: 0.6928
# Epoch 6/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 7/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6926 - val_loss: 0.6926
# Epoch 8/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.6925 - val_loss: 0.6925
# Epoch 9/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 10/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6923 - val_loss: 0.6923
# Epoch 11/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.6922 - val_loss: 0.6922
# Epoch 12/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 13/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6920 - val_loss: 0.6920
# Epoch 14/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.6919 - val_loss: 0.6919
# Epoch 15/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 16/50
# 235/235 [==============================] - 7s 32ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 17/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6916 - val_loss: 0.6916
# Epoch 18/50
# 235/235 [==============================] - 6s 25ms/step - loss: 0.6915 - val_loss: 0.6914
# Epoch 19/50
# 235/235 [==============================] - 8s 34ms/step - loss: 0.6914 - val_loss: 0.6913
# Epoch 20/50
# 235/235 [==============================] - 7s 31ms/step - loss: 0.6913 - val_loss: 0.6912
# Epoch 21/50
# 235/235 [==============================] - 8s 33ms/step - loss: 0.6912 - val_loss: 0.6911
# Epoch 22/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6911 - val_loss: 0.6910
# Epoch 23/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.6910 - val_loss: 0.6909
# Epoch 24/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6909 - val_loss: 0.6908
# Epoch 25/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6908 - val_loss: 0.6907
# Epoch 26/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6906 - val_loss: 0.6906
# Epoch 27/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.6905 - val_loss: 0.6905
# Epoch 28/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6904 - val_loss: 0.6903
# Epoch 29/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6903 - val_loss: 0.6902
# Epoch 30/50
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6902 - val_loss: 0.6901
# Epoch 31/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6900 - val_loss: 0.6900
# Epoch 32/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6899 - val_loss: 0.6898
# Epoch 33/50
# 235/235 [==============================] - 6s 23ms/step - loss: 0.6898 - val_loss: 0.6897
# Epoch 34/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6897 - val_loss: 0.6896
# Epoch 35/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6895 - val_loss: 0.6895
# Epoch 36/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.6894 - val_loss: 0.6893
# Epoch 37/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.6893 - val_loss: 0.6892
# Epoch 38/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6891 - val_loss: 0.6890
# Epoch 39/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.6890 - val_loss: 0.6889
# Epoch 40/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6888 - val_loss: 0.6887
# Epoch 41/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6887 - val_loss: 0.6886
# Epoch 42/50
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6885 - val_loss: 0.6884
# Epoch 43/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6884 - val_loss: 0.6883
# Epoch 44/50
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6882 - val_loss: 0.6881
# Epoch 45/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.6880 - val_loss: 0.6880
# Epoch 46/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6879 - val_loss: 0.6878
# Epoch 47/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6877 - val_loss: 0.6876
# Epoch 48/50
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6875 - val_loss: 0.6874
# Epoch 49/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6873 - val_loss: 0.6872
# Epoch 50/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6872 - val_loss: 0.6871
# 313/313 [==============================] - 1s 2ms/step
# Mean Reconstruction Error (MSE) on test set: 0.16661472618579865

# %%
# Visualize one of the reconstructed version of the test data and the original test data
n = 10  # Number of images to display
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(reconstructed_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# Plot loss and accuracy using the history object
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
#### for denoising

from keras.layers import Input, Dense
from keras.models import Model
import matplotlib.pyplot as plt
from keras.datasets import fashion_mnist
import numpy as np

# this is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats


# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)
# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)
# this model maps an input to its encoded representation
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# Load the Fashion MNIST dataset
(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Introducing noise
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Train the autoencoder
history = autoencoder.fit(x_train_noisy, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))

# Predict the reconstructed test set
reconstructed_imgs = autoencoder.predict(x_test_noisy)

# Compute the Mean Squared Error (MSE) for each sample
mse = np.mean(np.power(x_test - reconstructed_imgs, 2), axis=1)

# Calculate the mean reconstruction error
mean_mse = np.mean(mse)

print(f'Mean Reconstruction Error (MSE) on test set: {mean_mse}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 235/235 [==============================] - 3s 10ms/step - loss: 0.6943 - val_loss: 0.6942
# Epoch 2/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6941 - val_loss: 0.6940
# Epoch 3/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6939 - val_loss: 0.6938
# Epoch 4/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6937 - val_loss: 0.6937
# Epoch 5/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6935 - val_loss: 0.6935
# Epoch 6/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6934 - val_loss: 0.6933
# Epoch 7/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6932 - val_loss: 0.6932
# Epoch 8/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 9/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6929 - val_loss: 0.6928
# Epoch 10/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 11/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6926 - val_loss: 0.6925
# Epoch 12/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 13/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6923 - val_loss: 0.6922
# Epoch 14/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 15/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.6920 - val_loss: 0.6919
# Epoch 16/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 17/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6917 - val_loss: 0.6916
# Epoch 18/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6915 - val_loss: 0.6915
# Epoch 19/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6914 - val_loss: 0.6913
# Epoch 20/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 21/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6911 - val_loss: 0.6910
# Epoch 22/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6909 - val_loss: 0.6909
# Epoch 23/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6908 - val_loss: 0.6907
# Epoch 24/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6906 - val_loss: 0.6906
# Epoch 25/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6905 - val_loss: 0.6904
# Epoch 26/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 27/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6902 - val_loss: 0.6901
# Epoch 28/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6900 - val_loss: 0.6900
# Epoch 29/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6898 - val_loss: 0.6898
# Epoch 30/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.6897 - val_loss: 0.6896
# Epoch 31/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6895 - val_loss: 0.6895
# Epoch 32/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6893 - val_loss: 0.6893
# Epoch 33/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6892 - val_loss: 0.6891
# Epoch 34/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6890 - val_loss: 0.6889
# Epoch 35/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6888 - val_loss: 0.6887
# Epoch 36/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6886 - val_loss: 0.6886
# Epoch 37/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6884 - val_loss: 0.6884
# Epoch 38/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6882 - val_loss: 0.6882
# Epoch 39/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6880 - val_loss: 0.6880
# Epoch 40/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6878 - val_loss: 0.6878
# Epoch 41/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6876 - val_loss: 0.6875
# Epoch 42/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6874 - val_loss: 0.6873
# Epoch 43/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6872 - val_loss: 0.6871
# Epoch 44/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6869 - val_loss: 0.6869
# Epoch 45/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6867 - val_loss: 0.6866
# Epoch 46/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6865 - val_loss: 0.6864
# Epoch 47/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6862 - val_loss: 0.6861
# Epoch 48/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6860 - val_loss: 0.6859
# Epoch 49/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6857 - val_loss: 0.6856
# Epoch 50/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.6854 - val_loss: 0.6853
# 313/313 [==============================] - 1s 1ms/step
# Mean Reconstruction Error (MSE) on test set: 0.1657627671957016

# %%
# Visualize the original noisy image and the reconstructed image
n = 1  # Index of the image to be visualized
plt.figure(figsize=(20, 4))
plt.subplot(1, 2, 1)
plt.title("Original Noisy Image")
plt.imshow(x_test_noisy[n].reshape(28, 28), cmap="gray")
plt.subplot(1, 2, 2)
plt.title("Reconstructed Image")
plt.imshow(reconstructed_imgs[n].reshape(28, 28), cmap="gray")
plt.show()

# %%
# Plotting training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()
